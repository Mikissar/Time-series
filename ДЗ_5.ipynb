# %%
import pandas as pd  # Импорт библиотеки Pandas для работы с данными в виде таблицы DataFrame
import numpy as np  # Импорт библиотеки NumPy для работы с массивами и математическими операциями
from matplotlib import pyplot as plt  # Импорт библиотеки Matplotlib для визуализации данных
from scipy.stats import f  # Импорт функции для работы с распределением F из библиотеки SciPy
from google.colab import drive  # Импорт библиотеки для работы с Google Drive (предположительно, в Google Colab)

# %%
drive.mount('/content/gdrive') # Монтируем Google Диск
data_tweet = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/Time series/vaccination_all_tweets.csv')
data_vac = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/Time series/vaccinations.csv')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
data_vac = (data_vac.groupby('date')  # Группировка данных по дате
    .agg({'location': 'count', 'daily_vaccinations': 'sum'})  # Применение агрегирующих функций к каждой группе
    .reset_index()  # Сброс индексов, чтобы получить обычный DataFrame
    .rename(columns={'location': 'counties_count'})  # Переименование столбцов
)

# %%
data_vac.tail(10)  # Вывод последних 10 строк DataFrame data_vac
# Out:
#            date  counties_count  daily_vaccinations
# 260  2021-08-19             193         146862864.0
# 261  2021-08-20             191         145618292.0
# 262  2021-08-21             183         142912307.0
# 263  2021-08-22             180         144835334.0
# 264  2021-08-23             174         140097443.0
# 265  2021-08-24             158         141618411.0
# 266  2021-08-25             150         144342936.0
# 267  2021-08-26             127         147456968.0
# 268  2021-08-27             105         148928388.0
# 269  2021-08-28              61         145209039.0

# %%
plt.plot(data_vac.date, data_vac["daily_vaccinations"])  # Построение графика по дате и ежедневному количеству вакцинаций
plt.xlabel('Дата')  # Название оси x
plt.ylabel('Ежедневное количество вакцинаций')  # Название оси y
plt.title('График ежедневного количества вакцинаций')  # Заголовок графика
plt.show()  # Отображение графика

# %%
data_tweet.head()  # Вывод первых 5 строк DataFrame data_tweet
# Out:
#                     id             user_name              user_location  \
# 0  1340539111971516416            Rachel Roh  La Crescenta-Montrose, CA
# 1  1338158543359250433           Albert Fong          San Francisco, CA
# 2  1337858199140118533              eli🇱🇹🇪🇺👌                   Your Bed
# 3  1337855739918835717         Charles Adler     Vancouver, BC - Canada
# 4  1337854064604966912  Citizen News Channel                        NaN
#
#                                     user_description         user_created  \
# 0  Aggregator of Asian American news; scanning di...  2009-04-08 17:52:46
# 1  Marketing dude, tech geek, heavy metal & '80s ...  2009-09-21 15:27:30
# 2                                     heil, hydra 🖐☺  2020-06-25 23:30:28
# 3  Hosting "CharlesAdlerTonight" Global News Radi...  2008-09-10 11:28:53
# 4  Citizen News Channel bringing you an alternati...  2020-04-23 17:58:42
#
#    user_followers  user_friends  user_favourites  user_verified  \
# 0             405          1692             3247          False
# 1             834           666              178          False
# 2              10            88              155          False
# 3           49165          3933            21853           True
# 4             152           580             1473          False
#
#                   date                                               text  \
# 0  2020-12-20 06:06:44  Same folks said daikon paste could treat a cyt...
# 1  2020-12-13 16:27:13  While the world has been on the wrong side of ...
# 2  2020-12-12 20:33:45  #coronavirus #SputnikV #AstraZeneca #PfizerBio...
# 3  2020-12-12 20:23:59  Facts are immutable, Senator, even when you're...
# 4  2020-12-12 20:17:19  Explain to me again why we need a vaccine @Bor...
#
#                                             hashtags               source  \
# 0                                 ['PfizerBioNTech']  Twitter for Android
# 1                                                NaN      Twitter Web App
# 2  ['coronavirus', 'SputnikV', 'AstraZeneca', 'Pf...  Twitter for Android
# 3                                                NaN      Twitter Web App
# 4     ['whereareallthesickpeople', 'PfizerBioNTech']   Twitter for iPhone
#
#    retweets  favorites  is_retweet
# 0         0          0       False
# 1         1          1       False
# 2         0          0       False
# 3       446       2129       False
# 4         0          0       False

# %%
data_tweet['date'] = pd.to_datetime(data_tweet['date'], format='%Y-%m-%d %H:%M:%S')  # Преобразование столбца 'date' в формат datetime

# %%
data_tweet = (data_tweet.groupby(data_tweet['date'].dt.date)  # Группировка данных по дате (без времени)
    .agg({'retweets': 'sum'})  # Суммирование значения 'retweets' для каждой группы
    .reset_index()  # Сброс индексов, чтобы получить обычный DataFrame
)

# %%
data_tweet.head() # Вывод первых 5 строк DataFrame data_tweet
# Out:
#          date  retweets
# 0  2020-12-12       545
# 1  2020-12-13       164
# 2  2020-12-14       450
# 3  2020-12-15       200
# 4  2020-12-16       203

# %%
plt.plot(data_tweet["date"], data_tweet["retweets"])  # Построение графика по дате и суммарному количеству ретвитов
plt.xlabel('Дата')  # Название оси x
plt.ylabel('Суммарное количество ретвитов')  # Название оси y
plt.title('График суммарного количества ретвитов по датам')  # Заголовок графика
plt.show()  # Отображение графика

# %%
data_vac = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/Time series/vaccinations.csv')
data_vac = (data_vac.groupby('date')) \
    .agg({'location':'count', 'daily_vaccinations': 'sum'}) \
    .reset_index() \
    .rename(columns={'location':'counties_count'})

# %%
data = pd.DataFrame(data_vac)
data["tweets"] = data_tweet["retweets"]
data.tail(15)
# Out:
#            date  counties_count  daily_vaccinations  tweets
# 255  2021-08-14             210         149927600.0     888
# 256  2021-08-15             209         146754277.0     708
# 257  2021-08-16             206         146865385.0     497
# 258  2021-08-17             198         147057695.0     468
# 259  2021-08-18             195         146166823.0      64
# 260  2021-08-19             193         146862864.0     276
# 261  2021-08-20             191         145618292.0     301
# 262  2021-08-21             183         142912307.0     171
# 263  2021-08-22             180         144835334.0     150
# 264  2021-08-23             174         140097443.0     389
# 265  2021-08-24             158         141618411.0    1181
# 266  2021-08-25             150         144342936.0     515
# 267  2021-08-26             127         147456968.0     438
# 268  2021-08-27             105         148928388.0     239
# 269  2021-08-28              61         145209039.0    1325

# %% [markdown]
# ## дальше как на паре?

# %%
PREDICT_RANGE = 25

# %%
def AR(data_v, order, amount):
    kfs = np.ones(order)
    X_mat = []

    X_mat = np.array([data_v[i:order + i] for i in range(len(data_v) - order - 1)])

    kfs = np.linalg.lstsq(X_mat, data_v[order+1:len(data)])
    vect = data_v.values
    for i in range(amount):
        pred = kfs[0]@vect[-order:]
        vect = np.append(vect, pred)
    kmat = np.zeros((len(kfs[0]), len(kfs[0])))
    for i in range(len(kfs[0])):
        kmat[i,i] = kfs[0][i]
    #eigen = np.linalg.eig(kmat)
    # plt.scatter(np.real(kfs[0]), np.imag(kfs[0]))
    # plt.grid()
    return vect

# %%
daily_vac = data["daily_vaccinations"]
daily_tweet = data["tweets"]


predict_range = PREDICT_RANGE
lag = len(daily_vac) - predict_range - 2

pred = AR(daily_vac[:int(len(daily_vac)) - predict_range], lag ,predict_range)
# Out:
# <ipython-input-50-2b06a5fd7563>:7: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   kfs = np.linalg.lstsq(X_mat, data_v[order+1:len(data)])

# %%
plt.plot(daily_vac.values)
plt.plot(pred)

# %%
def co_AR(X, Y, order_x, order_y, amount):
    kfs = np.ones(order_x + order_y)

    # Создание лагированных временных рядов
    X_lagged = np.array([X[i:order_x + i] for i in range(len(X) - order_x - 1)])
    Y_lagged = np.array([Y[i:order_y + i] for i in range(len(Y) - order_y - 1)])

    # Формирование матрицы для теста
    XY_matrix = np.column_stack((X_lagged, Y_lagged))

    kfs = np.linalg.lstsq(XY_matrix, X[order_x+1:len(X)])
    vect_X = X.values
    vect_Y = Y.values
    for i in range(amount):
        pred = kfs[0]@ np.concatenate((vect_X[-order_x:], vect_Y[- order_y:]))
        vect_X = np.append(vect_X, pred)
    kmat = np.zeros((len(kfs[0]), len(kfs[0])))
    for i in range(len(kfs[0])):
        kmat[i,i] = kfs[0][i]
    #eigen = np.linalg.eig(kmat)
    return vect_X

# %%
daily_vac = data["daily_vaccinations"]
daily_tweet = data["tweets"]

predict_range = PREDICT_RANGE
lag = len(daily_vac) - predict_range - 2
pred_lag = co_AR(daily_vac[:int(len(daily_vac)) - predict_range], \
    daily_tweet[:int(len(daily_vac)) - predict_range], \
    lag, lag, predict_range)
# Out:
# <ipython-input-53-52aa8bac81af>:11: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   kfs = np.linalg.lstsq(XY_matrix, X[order_x+1:len(X)])

# %%
plt.plot(daily_vac.values)
plt.plot(pred)

# %% [markdown]
# ##Грейнджер

# %%
def calculate_f_statistic(y_with_lag, y_without_lag, p, q, n):
    """
    Расчет F-статистики для теста Грейнджера.

    Параметры:
    - y_with_lag: остатки модели с лагами
    - y_without_lag: остатки модели без лагов
    - p: количество лагированных значений, включенных в модель
    - q: количество коэффициентов регрессии
    - n: количество наблюдений в выборке

    Возвращает:
    - f_statistic: значение F-статистики
    - p_value: p-значение F-теста
    """

    mse_with_lag = np.mean(y_with_lag ** 2)
    mse_without_lag = np.mean(y_without_lag ** 2)

    f_statistic = ((mse_without_lag - mse_with_lag) / p) / (mse_with_lag / (n - p - q))
    p_value = f.sf(f_statistic, p, n - p - q)

    return f_statistic, p_value

n  = len(pred_lag)
f_statistic, p_value = calculate_f_statistic(pred_lag, pred, lag, 2, len(pred_lag))
print(f"F-Statistic: {f_statistic}, P-value: {p_value}")
critical=f.ppf(.95, 2, n - 3)#regression and residual deg of freedom
print('\nThe F-test critical p-value for a 95% significance level\nwith {:} and {:} degrees of freedom is {:.2f}'.format(
    2, n-3,critical))
print('\nsince {:.10f} < {:.2f}, the critical p-value, we can\'t reject the hyp. that\nthe lag members of Y is not belongs to X regression'.format(
f_statistic,critical))
# Out:
# F-Statistic: 5.021901235728486e-11, P-value: 0.9999999999999999
#
# The F-test critical p-value for a 95% significance level
# with 2 and 267 degrees of freedom is 3.03
#
# since 0.0000000001 < 3.03, the critical p-value, we can't reject the hyp. that
# the lag members of Y is not belongs to X regression

# %%
daily_vac = data["daily_vaccinations"]

predict_range = PREDICT_RANGE
lag = len(daily_vac) - predict_range - 2

daily_tweet = data["tweets"]
pred_lag = co_AR(daily_tweet[:int(len(daily_vac)) - predict_range], \
    daily_vac[:int(len(daily_vac)) - predict_range], \
    lag, lag, predict_range)
# Out:
# <ipython-input-53-52aa8bac81af>:11: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   kfs = np.linalg.lstsq(XY_matrix, X[order_x+1:len(X)])

# %%
plt.plot(daily_tweet.values)
plt.plot(pred_lag)

# %%
n  = len(pred)
f_statistic, p_value = calculate_f_statistic(pred, pred_lag, lag, 2, len(pred))
print(f"F-Statistic: {f_statistic}, P-value: {p_value}")
critical=f.ppf(.95, 2, n - 3)#regression and residual deg of freedom
print('\nThe F-test critical p-value for a 95% significance level\nwith {:} and {:} degrees of freedom is {:.2f}'.format(
    2, n-3,critical))
print('\nsince {:.2f} < {:.2f}, the critical p-value, we can\'t reject the hyp. that\nthe lag members of Y is not belongs to X regression.'.format(
f_statistic,critical))
# Out:
# F-Statistic: -0.10288065834831071, P-value: 1.0
#
# The F-test critical p-value for a 95% significance level
# with 2 and 267 degrees of freedom is 3.03
#
# since -0.10 < 3.03, the critical p-value, we can't reject the hyp. that
# the lag members of Y is not belongs to X regression.

# %%
import statsmodels.api as sm
from statsmodels.tsa.stattools import grangercausalitytests

X = daily_vac.values
Y = daily_tweet.values

# Подготовка данных в формате (Y, X) для теста Грейнджера
data = np.column_stack((X, Y))

# Проведение теста Грейнджера
max_lag = PREDICT_RANGE  # Максимальное количество лагированных значений
test_result = grangercausalitytests(data, max_lag, verbose=True)

# Интерпретация результатов
for lag in range(1, max_lag + 1):
    print(f"Results for lag {lag}:")
    p_value = test_result[lag][0]['ssr_ftest'][1]
    is_causal = p_value < 0.05
    print(f"P-value: {p_value}, Is causal: {is_causal}")
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/stattools.py:1545: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0115  , p=0.9146  , df_denom=266, df_num=1
# ssr based chi2 test:   chi2=0.0116  , p=0.9141  , df=1
# likelihood ratio test: chi2=0.0116  , p=0.9141  , df=1
# parameter F test:         F=0.0115  , p=0.9146  , df_denom=266, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.5920  , p=0.2055  , df_denom=263, df_num=2
# ssr based chi2 test:   chi2=3.2445  , p=0.1975  , df=2
# likelihood ratio test: chi2=3.2250  , p=0.1994  , df=2
# parameter F test:         F=1.5920  , p=0.2055  , df_denom=263, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.0111  , p=0.3883  , df_denom=260, df_num=3
# ssr based chi2 test:   chi2=3.1151  , p=0.3742  , df=3
# likelihood ratio test: chi2=3.0971  , p=0.3769  , df=3
# parameter F test:         F=1.0111  , p=0.3883  , df_denom=260, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.8508  , p=0.4942  , df_denom=257, df_num=4
# ssr based chi2 test:   chi2=3.5225  , p=0.4745  , df=4
# likelihood ratio test: chi2=3.4994  , p=0.4780  , df=4
# parameter F test:         F=0.8508  , p=0.4942  , df_denom=257, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.1479  , p=0.3356  , df_denom=254, df_num=5
# ssr based chi2 test:   chi2=5.9883  , p=0.3074  , df=5
# likelihood ratio test: chi2=5.9216  , p=0.3139  , df=5
# parameter F test:         F=1.1479  , p=0.3356  , df_denom=254, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.9525  , p=0.4581  , df_denom=251, df_num=6
# ssr based chi2 test:   chi2=6.0113  , p=0.4219  , df=6
# likelihood ratio test: chi2=5.9438  , p=0.4295  , df=6
# parameter F test:         F=0.9525  , p=0.4581  , df_denom=251, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.0183  , p=0.4187  , df_denom=248, df_num=7
# ssr based chi2 test:   chi2=7.5594  , p=0.3730  , df=7
# likelihood ratio test: chi2=7.4528  , p=0.3833  , df=7
# parameter F test:         F=1.0183  , p=0.4187  , df_denom=248, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.0197  , p=0.4216  , df_denom=245, df_num=8
# ssr based chi2 test:   chi2=8.7233  , p=0.3662  , df=8
# likelihood ratio test: chi2=8.5813  , p=0.3788  , df=8
# parameter F test:         F=1.0197  , p=0.4216  , df_denom=245, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.0508  , p=0.4003  , df_denom=242, df_num=9
# ssr based chi2 test:   chi2=10.1996 , p=0.3346  , df=9
# likelihood ratio test: chi2=10.0053 , p=0.3501  , df=9
# parameter F test:         F=1.0508  , p=0.4003  , df_denom=242, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.9474  , p=0.4904  , df_denom=239, df_num=10
# ssr based chi2 test:   chi2=10.3062 , p=0.4141  , df=10
# likelihood ratio test: chi2=10.1072 , p=0.4311  , df=10
# parameter F test:         F=0.9474  , p=0.4904  , df_denom=239, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=1.0853  , p=0.3737  , df_denom=236, df_num=11
# ssr based chi2 test:   chi2=13.1022 , p=0.2867  , df=11
# likelihood ratio test: chi2=12.7816 , p=0.3078  , df=11
# parameter F test:         F=1.0853  , p=0.3737  , df_denom=236, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=0.9829  , p=0.4659  , df_denom=233, df_num=12
# ssr based chi2 test:   chi2=13.0604 , p=0.3647  , df=12
# likelihood ratio test: chi2=12.7406 , p=0.3882  , df=12
# parameter F test:         F=0.9829  , p=0.4659  , df_denom=233, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=0.8962  , p=0.5578  , df_denom=230, df_num=13
# ssr based chi2 test:   chi2=13.0183 , p=0.4464  , df=13
# likelihood ratio test: chi2=12.6993 , p=0.4713  , df=13
# parameter F test:         F=0.8962  , p=0.5578  , df_denom=230, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=0.8950  , p=0.5650  , df_denom=227, df_num=14
# ssr based chi2 test:   chi2=14.1307 , p=0.4400  , df=14
# likelihood ratio test: chi2=13.7545 , p=0.4682  , df=14
# parameter F test:         F=0.8950  , p=0.5650  , df_denom=227, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=0.5717  , p=0.8947  , df_denom=224, df_num=15
# ssr based chi2 test:   chi2=9.7628  , p=0.8344  , df=15
# likelihood ratio test: chi2=9.5806  , p=0.8453  , df=15
# parameter F test:         F=0.5717  , p=0.8947  , df_denom=224, df_num=15
#
# Granger Causality
# number of lags (no zero) 16
# ssr based F test:         F=0.5590  , p=0.9116  , df_denom=221, df_num=16
# ssr based chi2 test:   chi2=10.2800 , p=0.8516  , df=16
# likelihood ratio test: chi2=10.0774 , p=0.8626  , df=16
# parameter F test:         F=0.5590  , p=0.9116  , df_denom=221, df_num=16
#
# Granger Causality
# number of lags (no zero) 17
# ssr based F test:         F=0.7695  , p=0.7270  , df_denom=218, df_num=17
# ssr based chi2 test:   chi2=15.1820 , p=0.5824  , df=17
# likelihood ratio test: chi2=14.7439 , p=0.6139  , df=17
# parameter F test:         F=0.7695  , p=0.7270  , df_denom=218, df_num=17
#
# Granger Causality
# number of lags (no zero) 18
# ssr based F test:         F=0.7250  , p=0.7835  , df_denom=215, df_num=18
# ssr based chi2 test:   chi2=15.2962 , p=0.6415  , df=18
# likelihood ratio test: chi2=14.8499 , p=0.6722  , df=18
# parameter F test:         F=0.7250  , p=0.7835  , df_denom=215, df_num=18
#
# Granger Causality
# number of lags (no zero) 19
# ssr based F test:         F=0.7005  , p=0.8164  , df_denom=212, df_num=19
# ssr based chi2 test:   chi2=15.7577 , p=0.6734  , df=19
# likelihood ratio test: chi2=15.2828 , p=0.7045  , df=19
# parameter F test:         F=0.7005  , p=0.8164  , df_denom=212, df_num=19
#
# Granger Causality
# number of lags (no zero) 20
# ssr based F test:         F=0.7255  , p=0.7975  , df_denom=209, df_num=20
# ssr based chi2 test:   chi2=17.3567 , p=0.6297  , df=20
# likelihood ratio test: chi2=16.7807 , p=0.6672  , df=20
# parameter F test:         F=0.7255  , p=0.7975  , df_denom=209, df_num=20
#
# Granger Causality
# number of lags (no zero) 21
# ssr based F test:         F=0.6786  , p=0.8516  , df_denom=206, df_num=21
# ssr based chi2 test:   chi2=17.2241 , p=0.6974  , df=21
# likelihood ratio test: chi2=16.6545 , p=0.7318  , df=21
# parameter F test:         F=0.6786  , p=0.8516  , df_denom=206, df_num=21
#
# Granger Causality
# number of lags (no zero) 22
# ssr based F test:         F=0.6340  , p=0.8963  , df_denom=203, df_num=22
# ssr based chi2 test:   chi2=17.0395 , p=0.7612  , df=22
# likelihood ratio test: chi2=16.4796 , p=0.7914  , df=22
# parameter F test:         F=0.6340  , p=0.8963  , df_denom=203, df_num=22
#
# Granger Causality
# number of lags (no zero) 23
# ssr based F test:         F=0.6720  , p=0.8696  , df_denom=200, df_num=23
# ssr based chi2 test:   chi2=19.0884 , p=0.6961  , df=23
# likelihood ratio test: chi2=18.3867 , p=0.7362  , df=23
# parameter F test:         F=0.6720  , p=0.8696  , df_denom=200, df_num=23
#
# Granger Causality
# number of lags (no zero) 24
# ssr based F test:         F=0.6454  , p=0.8976  , df_denom=197, df_num=24
# ssr based chi2 test:   chi2=19.3426 , p=0.7335  , df=24
# likelihood ratio test: chi2=18.6198 , p=0.7719  , df=24
# parameter F test:         F=0.6454  , p=0.8976  , df_denom=197, df_num=24
#
# Granger Causality
# number of lags (no zero) 25
# ssr based F test:         F=0.6386  , p=0.9077  , df_denom=194, df_num=25
# ssr based chi2 test:   chi2=20.1613 , p=0.7383  , df=25
# likelihood ratio test: chi2=19.3746 , p=0.7788  , df=25
# parameter F test:         F=0.6386  , p=0.9077  , df_denom=194, df_num=25
# Results for lag 1:
# P-value: 0.9146468084164019, Is causal: False
# Results for lag 2:
# P-value: 0.2054750500282227, Is causal: False
# Results for lag 3:
# P-value: 0.388298454905662, Is causal: False
# Results for lag 4:
# P-value: 0.4941649821935181, Is causal: False
# Results for lag 5:
# P-value: 0.33555395051545356, Is causal: False
# Results for lag 6:
# P-value: 0.4580927723399044, Is causal: False
# Results for lag 7:
# P-value: 0.4187290538770867, Is causal: False
# Results for lag 8:
# P-value: 0.4216325925281955, Is causal: False
# Results for lag 9:
# P-value: 0.40030269948696723, Is causal: False
# Results for lag 10:
# P-value: 0.4904402614599762, Is causal: False
# Results for lag 11:
# P-value: 0.37374595065363986, Is causal: False
# Results for lag 12:
# P-value: 0.46590358053535597, Is causal: False
# Results for lag 13:
# P-value: 0.5578302902201763, Is causal: False
# Results for lag 14:
# P-value: 0.5649803910168836, Is causal: False
# Results for lag 15:
# P-value: 0.8947196129366731, Is causal: False
# Results for lag 16:
# P-value: 0.9116269966691314, Is causal: False
# Results for lag 17:
# P-value: 0.7270253168860354, Is causal: False
# Results for lag 18:
# P-value: 0.7834820534110761, Is causal: False
# Results for lag 19:
# P-value: 0.8164481394294422, Is causal: False
# Results for lag 20:
# P-value: 0.7974857485205878, Is causal: False
# Results for lag 21:
# P-value: 0.8515976835861456, Is causal: False
# Results for lag 22:
# P-value: 0.8962914070454949, Is causal: False
# Results for lag 23:
# P-value: 0.8695514260374392, Is causal: False
# Results for lag 24:
# P-value: 0.8975862932621219, Is causal: False
# Results for lag 25:
# P-value: 0.907650381317739, Is causal: False

# %%
print(f"Results for lag {PREDICT_RANGE}:")
p_value = test_result[PREDICT_RANGE][0]['ssr_ftest'][1]
is_causal = p_value < 0.05
print(f"P-value: {p_value}, Is causal: {is_causal}")
# Out:
# Results for lag 25:
# P-value: 0.907650381317739, Is causal: False

# %%
# Подготовка данных в формате (Y, X) для теста Грейнджера
data = np.column_stack((Y, X))

# Проведение теста Грейнджера
max_lag = PREDICT_RANGE  # Максимальное количество лагированных значений
test_result = grangercausalitytests(data, max_lag, verbose=True)

# Интерпретация результатов
for lag in range(1, max_lag + 1):
    print(f"Results for lag {lag}:")
    p_value = test_result[lag][0]['ssr_ftest'][1]
    is_causal = p_value < 0.05
    print(f"P-value: {p_value}, Is causal: {is_causal}")
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0632  , p=0.8017  , df_denom=266, df_num=1
# ssr based chi2 test:   chi2=0.0639  , p=0.8004  , df=1
# likelihood ratio test: chi2=0.0639  , p=0.8004  , df=1
# parameter F test:         F=0.0632  , p=0.8017  , df_denom=266, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.2146  , p=0.8070  , df_denom=263, df_num=2
# ssr based chi2 test:   chi2=0.4373  , p=0.8036  , df=2
# likelihood ratio test: chi2=0.4370  , p=0.8037  , df=2
# parameter F test:         F=0.2146  , p=0.8070  , df_denom=263, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.2984  , p=0.8265  , df_denom=260, df_num=3
# ssr based chi2 test:   chi2=0.9194  , p=0.8207  , df=3
# likelihood ratio test: chi2=0.9178  , p=0.8211  , df=3
# parameter F test:         F=0.2984  , p=0.8265  , df_denom=260, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.7514  , p=0.5579  , df_denom=257, df_num=4
# ssr based chi2 test:   chi2=3.1107  , p=0.5395  , df=4
# likelihood ratio test: chi2=3.0926  , p=0.5424  , df=4
# parameter F test:         F=0.7514  , p=0.5579  , df_denom=257, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.7241  , p=0.6059  , df_denom=254, df_num=5
# ssr based chi2 test:   chi2=3.7772  , p=0.5819  , df=5
# likelihood ratio test: chi2=3.7505  , p=0.5859  , df=5
# parameter F test:         F=0.7241  , p=0.6059  , df_denom=254, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.7389  , p=0.6188  , df_denom=251, df_num=6
# ssr based chi2 test:   chi2=4.6630  , p=0.5877  , df=6
# likelihood ratio test: chi2=4.6223  , p=0.5931  , df=6
# parameter F test:         F=0.7389  , p=0.6188  , df_denom=251, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.7212  , p=0.6541  , df_denom=248, df_num=7
# ssr based chi2 test:   chi2=5.3537  , p=0.6169  , df=7
# likelihood ratio test: chi2=5.2999  , p=0.6234  , df=7
# parameter F test:         F=0.7212  , p=0.6541  , df_denom=248, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.5272  , p=0.8356  , df_denom=245, df_num=8
# ssr based chi2 test:   chi2=4.5101  , p=0.8084  , df=8
# likelihood ratio test: chi2=4.4718  , p=0.8123  , df=8
# parameter F test:         F=0.5272  , p=0.8356  , df_denom=245, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.4996  , p=0.8740  , df_denom=242, df_num=9
# ssr based chi2 test:   chi2=4.8497  , p=0.8472  , df=9
# likelihood ratio test: chi2=4.8052  , p=0.8509  , df=9
# parameter F test:         F=0.4996  , p=0.8740  , df_denom=242, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.6440  , p=0.7752  , df_denom=239, df_num=10
# ssr based chi2 test:   chi2=7.0062  , p=0.7249  , df=10
# likelihood ratio test: chi2=6.9135  , p=0.7336  , df=10
# parameter F test:         F=0.6440  , p=0.7752  , df_denom=239, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=1.4061  , p=0.1707  , df_denom=236, df_num=11
# ssr based chi2 test:   chi2=16.9743 , p=0.1086  , df=11
# likelihood ratio test: chi2=16.4412 , p=0.1255  , df=11
# parameter F test:         F=1.4061  , p=0.1707  , df_denom=236, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=1.2374  , p=0.2582  , df_denom=233, df_num=12
# ssr based chi2 test:   chi2=16.4422 , p=0.1718  , df=12
# likelihood ratio test: chi2=15.9395 , p=0.1940  , df=12
# parameter F test:         F=1.2374  , p=0.2582  , df_denom=233, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=1.2019  , p=0.2786  , df_denom=230, df_num=13
# ssr based chi2 test:   chi2=17.4596 , p=0.1791  , df=13
# likelihood ratio test: chi2=16.8921 , p=0.2043  , df=13
# parameter F test:         F=1.2019  , p=0.2786  , df_denom=230, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=1.2087  , p=0.2699  , df_denom=227, df_num=14
# ssr based chi2 test:   chi2=19.0830 , p=0.1618  , df=14
# likelihood ratio test: chi2=18.4052 , p=0.1889  , df=14
# parameter F test:         F=1.2087  , p=0.2699  , df_denom=227, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=1.1248  , p=0.3350  , df_denom=224, df_num=15
# ssr based chi2 test:   chi2=19.2075 , p=0.2045  , df=15
# likelihood ratio test: chi2=18.5185 , p=0.2364  , df=15
# parameter F test:         F=1.1248  , p=0.3350  , df_denom=224, df_num=15
#
# Granger Causality
# number of lags (no zero) 16
# ssr based F test:         F=1.0211  , p=0.4353  , df_denom=221, df_num=16
# ssr based chi2 test:   chi2=18.7767 , p=0.2804  , df=16
# likelihood ratio test: chi2=18.1151 , p=0.3172  , df=16
# parameter F test:         F=1.0211  , p=0.4353  , df_denom=221, df_num=16
#
# Granger Causality
# number of lags (no zero) 17
# ssr based F test:         F=1.0925  , p=0.3624  , df_denom=218, df_num=17
# ssr based chi2 test:   chi2=21.5535 , p=0.2025  , df=17
# likelihood ratio test: chi2=20.6844 , p=0.2407  , df=17
# parameter F test:         F=1.0925  , p=0.3624  , df_denom=218, df_num=17
#
# Granger Causality
# number of lags (no zero) 18
# ssr based F test:         F=1.0134  , p=0.4458  , df_denom=215, df_num=18
# ssr based chi2 test:   chi2=21.3796 , p=0.2607  , df=18
# likelihood ratio test: chi2=20.5209 , p=0.3043  , df=18
# parameter F test:         F=1.0134  , p=0.4458  , df_denom=215, df_num=18
#
# Granger Causality
# number of lags (no zero) 19
# ssr based F test:         F=0.9200  , p=0.5587  , df_denom=212, df_num=19
# ssr based chi2 test:   chi2=20.6956 , p=0.3539  , df=19
# likelihood ratio test: chi2=19.8865 , p=0.4014  , df=19
# parameter F test:         F=0.9200  , p=0.5587  , df_denom=212, df_num=19
#
# Granger Causality
# number of lags (no zero) 20
# ssr based F test:         F=0.8798  , p=0.6130  , df_denom=209, df_num=20
# ssr based chi2 test:   chi2=21.0474 , p=0.3943  , df=20
# likelihood ratio test: chi2=20.2082 , p=0.4450  , df=20
# parameter F test:         F=0.8798  , p=0.6130  , df_denom=209, df_num=20
#
# Granger Causality
# number of lags (no zero) 21
# ssr based F test:         F=0.8954  , p=0.5973  , df_denom=206, df_num=21
# ssr based chi2 test:   chi2=22.7276 , p=0.3587  , df=21
# likelihood ratio test: chi2=21.7495 , p=0.4141  , df=21
# parameter F test:         F=0.8954  , p=0.5973  , df_denom=206, df_num=21
#
# Granger Causality
# number of lags (no zero) 22
# ssr based F test:         F=0.8579  , p=0.6501  , df_denom=203, df_num=22
# ssr based chi2 test:   chi2=23.0584 , p=0.3984  , df=22
# likelihood ratio test: chi2=22.0486 , p=0.4570  , df=22
# parameter F test:         F=0.8579  , p=0.6501  , df_denom=203, df_num=22
#
# Granger Causality
# number of lags (no zero) 23
# ssr based F test:         F=0.8079  , p=0.7194  , df_denom=200, df_num=23
# ssr based chi2 test:   chi2=22.9477 , p=0.4638  , df=23
# likelihood ratio test: chi2=21.9434 , p=0.5237  , df=23
# parameter F test:         F=0.8079  , p=0.7194  , df_denom=200, df_num=23
#
# Granger Causality
# number of lags (no zero) 24
# ssr based F test:         F=0.7550  , p=0.7889  , df_denom=197, df_num=24
# ssr based chi2 test:   chi2=22.6282 , p=0.5418  , df=24
# likelihood ratio test: chi2=21.6472 , p=0.6003  , df=24
# parameter F test:         F=0.7550  , p=0.7889  , df_denom=197, df_num=24
#
# Granger Causality
# number of lags (no zero) 25
# ssr based F test:         F=0.8255  , p=0.7064  , df_denom=194, df_num=25
# ssr based chi2 test:   chi2=26.0625 , p=0.4043  , df=25
# likelihood ratio test: chi2=24.7673 , p=0.4755  , df=25
# parameter F test:         F=0.8255  , p=0.7064  , df_denom=194, df_num=25
# Results for lag 1:
# P-value: 0.8017062800529162, Is causal: False
# Results for lag 2:
# P-value: 0.8070162909150425, Is causal: False
# Results for lag 3:
# P-value: 0.826516086713499, Is causal: False
# Results for lag 4:
# P-value: 0.557891811954118, Is causal: False
# Results for lag 5:
# P-value: 0.605915168411729, Is causal: False
# Results for lag 6:
# P-value: 0.6187589664756457, Is causal: False
# Results for lag 7:
# P-value: 0.6541296394163569, Is causal: False
# Results for lag 8:
# P-value: 0.8355545131248315, Is causal: False
# Results for lag 9:
# P-value: 0.8740254083124154, Is causal: False
# Results for lag 10:
# P-value: 0.7751793037776109, Is causal: False
# Results for lag 11:
# P-value: 0.17072475111268673, Is causal: False
# Results for lag 12:
# P-value: 0.25820704712035536, Is causal: False
# Results for lag 13:
# P-value: 0.27864306827646634, Is causal: False
# Results for lag 14:
# P-value: 0.2699358686510394, Is causal: False
# Results for lag 15:
# P-value: 0.3350406789357423, Is causal: False
# Results for lag 16:
# P-value: 0.4353393379150287, Is causal: False
# Results for lag 17:
# P-value: 0.3623572078412133, Is causal: False
# Results for lag 18:
# P-value: 0.4458063765543884, Is causal: False
# Results for lag 19:
# P-value: 0.5587165915396837, Is causal: False
# Results for lag 20:
# P-value: 0.6130496462300012, Is causal: False
# Results for lag 21:
# P-value: 0.5973326425834005, Is causal: False
# Results for lag 22:
# P-value: 0.6501418902169259, Is causal: False
# Results for lag 23:
# P-value: 0.7193702127532827, Is causal: False
# Results for lag 24:
# P-value: 0.7889111617454618, Is causal: False
# Results for lag 25:
# P-value: 0.7063701815674652, Is causal: False

# %%
print(f"Results for lag {PREDICT_RANGE}:")
p_value = test_result[PREDICT_RANGE][0]['ssr_ftest'][1]
is_causal = p_value < 0.05
print(f"P-value: {p_value}, Is causal: {is_causal}")
# Out:
# Results for lag 25:
# P-value: 0.7063701815674652, Is causal: False

# %% [markdown]
# ## Выводы
#
# Значение p теста составляет 0,71. Поскольку это значение не меньше 0,05, мы не можем отвергнуть нулевую гипотезу. То есть количество вакцинаций не является предсказанием количества твитов о вакцинации
